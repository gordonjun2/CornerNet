# %%
import os
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import sys
import json

# %%
with open('CornerNet.json', 'r') as f:
    json_file = json.load(f)

# %%
json_file.keys()
# Out:
# dict_keys(['system', 'db'])

# %%
json_file['system'].keys()
# Out:
# dict_keys(['dataset', 'batch_size', 'sampling_function', 'train_split', 'val_split', 'learning_rate', 'decay_rate', 'val_iter', 'opt_algo', 'prefetch_size', 'max_iter', 'stepsize', 'snapshot', 'chunk_sizes', 'data_dir'])

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\Gordon\\CornerNet\\config'

# %%
sys.path.append('C:\\Users\\User\\Desktop\\Gordon\\CornerNet\\data\\coco\\annotations')
sys.path.append('C:\\Users\\User\\Desktop\\Gordon\\CornerNet\\data\\coco\\images')

# %%
with open(os.path.join(os.getcwd(), '..', 'data','coco','annotations', 'instances_minival2014.json'), 'r') as f:
    json_file = json.load(f)

# %%
json_file.keys()
# Out:
# dict_keys(['info', 'licenses', 'images', 'type', 'annotations', 'categories'])

# %%
json_file['images'][0]['file_name']
# Out:
# 'COCO_val2014_000000397133.jpg'

# %%
im = Image.open(os.path.join(os.getcwd(), '..', 'data','coco','images', 'minival2014', json_file['images'][0]['file_name']))

# %%
len(json_file['categories'])
# Out:
# 80

# %%
class_dict = {}
for temp_dict in json_file['categories']:
    class_dict[temp_dict['id']] = temp_dict['name']
class_dict
# Out:
# {1: 'person',
#  2: 'bicycle',
#  3: 'car',
#  4: 'motorcycle',
#  5: 'airplane',
#  6: 'bus',
#  7: 'train',
#  8: 'truck',
#  9: 'boat',
#  10: 'traffic light',
#  11: 'fire hydrant',
#  13: 'stop sign',
#  14: 'parking meter',
#  15: 'bench',
#  16: 'bird',
#  17: 'cat',
#  18: 'dog',
#  19: 'horse',
#  20: 'sheep',
#  21: 'cow',
#  22: 'elephant',
#  23: 'bear',
#  24: 'zebra',
#  25: 'giraffe',
#  27: 'backpack',
#  28: 'umbrella',
#  31: 'handbag',
#  32: 'tie',
#  33: 'suitcase',
#  34: 'frisbee',
#  35: 'skis',
#  36: 'snowboard',
#  37: 'sports ball',
#  38: 'kite',
#  39: 'baseball bat',
#  40: 'baseball glove',
#  41: 'skateboard',
#  42: 'surfboard',
#  43: 'tennis racket',
#  44: 'bottle',
#  46: 'wine glass',
#  47: 'cup',
#  48: 'fork',
#  49: 'knife',
#  50: 'spoon',
#  51: 'bowl',
#  52: 'banana',
#  53: 'apple',
#  54: 'sandwich',
#  55: 'orange',
#  56: 'broccoli',
#  57: 'carrot',
#  58: 'hot dog',
#  59: 'pizza',
#  60: 'donut',
#  61: 'cake',
#  62: 'chair',
# ...

# %%
for ann in json_file['annotations']:
    print(ann['category_id'], class_dict[ann['category_id']])
# Out:
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 18 dog
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 64 potted plant
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 72 tv
# 16 bird
# 16 bird
# 16 bird
# 16 bird
# 16 bird
# 16 bird
# 17 cat
# 17 cat
# 17 cat
# 17 cat
# 17 cat
# 17 cat
# 17 cat
# 17 cat
# 17 cat
# 17 cat
# 17 cat
# 17 cat
# 17 cat
# 17 cat
# ...

# %%
json_file['annotations'][0].keys()
# Out:
# dict_keys(['segmentation', 'area', 'iscrowd', 'image_id', 'bbox', 'category_id', 'id'])

# %%
json_file['annotations'][0]['bbox']
# Out:
# [473.07, 395.93, 38.65, 28.67]

# %%
json_file['annotations'][0]['image_id']
# Out:
# 289343

# %%
draw = ImageDraw.Draw(im)
draw.rectangle(json_file['annotations'][0]['bbox'])

# %%
plt.imshow(im)
